# %%
import pandas as pd

# %%
df=pd.read_csv('/content/50_Startups (1).csv')

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        108 non-null    float64
#  1   Administration   108 non-null    float64
#  2   Marketing Spend  108 non-null    float64
#  3   State            108 non-null    object
#  4   Profit           108 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 4.3+ KB

# %%
df.isnull().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        108 non-null    float64
#  1   Administration   108 non-null    float64
#  2   Marketing Spend  108 non-null    float64
#  3   State            108 non-null    object
#  4   Profit           108 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 4.3+ KB

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df['State']=le.fit_transform(df['State'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        108 non-null    float64
#  1   Administration   108 non-null    float64
#  2   Marketing Spend  108 non-null    float64
#  3   State            108 non-null    int64
#  4   Profit           108 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 4.3 KB

# %%
x= df.drop('Profit',axis=1)

# %%
y=df['Profit']

# %%
x
# Out:
#      R&D Spend  Administration  Marketing Spend  State
# 0    165349.20       136897.80        471784.10      2
# 1    162597.70       151377.59        443898.53      0
# 2    153441.51       101145.55        407934.54      1
# 3    144372.41       118671.85        383199.62      2
# 4    142107.34        91391.77        366168.42      1
# ..         ...             ...              ...    ...
# 103  119943.24       156547.42        256512.92      1
# 104  114523.61       122616.84        261776.23      2
# 105   78013.11       121597.55        264346.06      0
# 106   94657.16       145077.58        282574.31      2
# 107   91749.16       114175.79        294919.57      1
#
# [108 rows x 4 columns]

# %%
y
# Out:
# 0      192261.83
# 1      191792.06
# 2      191050.39
# 3      182901.99
# 4      166187.94
#          ...
# 103    132602.65
# 104    129917.04
# 105    126992.93
# 106    125370.37
# 107    124266.90
# Name: Profit, Length: 108, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=12)

# %%
xtrain
# Out:
#      R&D Spend  Administration  Marketing Spend  State
# 45     1000.23       124153.04          1903.93      2
# 73    46426.07       157693.92        210797.67      2
# 105   78013.11       121597.55        264346.06      0
# 50   100671.96        91790.61        249744.55      0
# 18    91749.16       114175.79        294919.57      1
# 63    77044.01        99281.34        140574.81      2
# 30    61994.48       115641.28         91131.24      1
# 33    55493.95       103057.49        214634.81      1
# 86        0.00       135426.92             0.00      0
# 62    67532.53       105751.03        304768.73      1
# 35    46014.02        85047.44        205517.64      2
# 82    20229.59       127382.30         35534.17      2
# 95   134615.46       147198.87        127716.82      0
# 101   93863.75       127320.38        249839.44      1
# 0    165349.20       136897.80        471784.10      2
# 74    20229.59        85047.44        205517.64      2
# 107   91749.16       114175.79        294919.57      1
# 34    46426.07       157693.92        210797.67      0
# 89   165349.20       136897.80        471784.10      2
# 13    91992.39       135495.07        252664.93      0
# 5    131876.90        99814.71        362861.36      2
# 52    91992.39       135495.07        252664.93      0
# 49        0.00       116983.80         45173.06      0
# 22    73994.56       122782.75        303319.26      1
# 48      542.05        51743.15             0.00      2
# 76    44069.95        51283.14        197029.42      0
# 67    66051.52       182645.56        118148.20      1
# 3    144372.41       118671.85        383199.62      2
# 2    153441.51       101145.55        407934.54      1
# 6    134615.46       147198.87        127716.82      0
# 27    72107.60       127864.55        353183.81      2
# 75    28663.76       127056.21        201126.82      1

# %%
xtest
# Out:
#      R&D Spend  Administration  Marketing Spend  State
# 36    28663.76       127056.21        201126.82      1
# 21    78389.47       153773.43        299737.29      2
# 19    86419.70       153514.11             0.00      2
# 98   123334.88       108679.17        304981.62      0
# 39    38558.51        82982.09        174999.30      0
# 14   119943.24       156547.42        256512.92      1
# 102   91992.39       135495.07        252664.93      0
# 60    78389.47       153773.43        299737.29      2
# 26    75328.87       144135.98        134050.07      1
# 81    23640.93        96189.63        148001.11      0
# 7    130298.13       145530.06        323876.68      1
# 40    28754.33       118546.05        172795.67      0
# 31    61136.38       152701.92         88218.23      2
# 17    94657.16       145077.58        282574.31      2
# 97   120542.52       148718.95        311613.29      2
# 8    120542.52       148718.95        311613.29      2
# 46     1315.46       115816.21        297114.46      1
# 92   144372.41       118671.85        383199.62      2
# 85     1315.46       115816.21        297114.46      1
# 9    123334.88       108679.17        304981.62      0
# 51    93863.75       127320.38        249839.44      1
# 58    86419.70       153514.11             0.00      2
# 12    93863.75       127320.38        249839.44      1
# 68    65605.48       153032.06        107138.38      2
# 1    162597.70       151377.59        443898.53      0
# 15   114523.61       122616.84        261776.23      2
# 38    20229.59        65947.93        185265.10      2
# 24    77044.01        99281.34        140574.81      2
# 99   101913.08       110594.11        229160.95      1
# 70    20229.59       152701.92         88218.23      2
# 23    67532.53       105751.03        304768.73      1
# 88        0.00       116983.80         45173.06      0
# 54   114523.61       122616.84        261776.23      2

# %%
y
# Out:
# 0      192261.83
# 1      191792.06
# 2      191050.39
# 3      182901.99
# 4      166187.94
#          ...
# 103    132602.65
# 104    129917.04
# 105    126992.93
# 106    125370.37
# 107    124266.90
# Name: Profit, Length: 108, dtype: float64

# %%
print(xtrain.shape,xtest.shape,ytrain.shape,ytest.shape)
# Out:
# (75, 4) (33, 4) (75,) (33,)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
# Predicting the values for xtest
ypred=lr.predict(xtest)

# %%
ypred
# Out:
# array([ 78536.8850366 , 118930.06609663, 111321.37208331, 154888.04976157,
#         86240.78543535, 148576.90796635, 128619.38343927, 118930.06609663,
#        109975.82278681,  73634.38273672, 159569.7774729 ,  78145.7752363 ,
#         96480.34549124, 130452.85085879, 151010.62893674, 151010.62893674,
#         62707.87963438, 172611.64327062,  62707.87963438, 154888.04976157,
#        129379.63118246, 111321.37208331, 129379.63118246, 100666.5268448 ,
#        189663.54240824, 144758.94239398,  72032.12705457, 111746.70814376,
#        134766.11501242,  65965.30141109, 112643.76385531,  50933.67262722,
#        144758.94239398])

# %%
# Classification report and confusion matrix can be used only with classification
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(ytest,ypred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-83c76beb9979> in <cell line: 1>()
# ----> 1 print(classification_report(ytest,ypred))
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    2308     """
#    2309
# -> 2310     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    2311
#    2312     if labels is None:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#     104     # No metrics support "multiclass-multioutput" format
#     105     if y_type not in ["binary", "multiclass", "multilabel-indicator"]:
# --> 106         raise ValueError("{0} is not supported".format(y_type))
#     107
#     108     if y_type in ["binary", "multiclass"]:
#
# ValueError: continuous is not supported

# %%
from sklearn.metrics import r2_score

# %%
r2_score(ytest,ypred)*100
# Out:
# 89.95591788218572
